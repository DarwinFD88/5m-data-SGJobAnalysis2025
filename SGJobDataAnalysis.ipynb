# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file
df = pd.read_csv('data/SGJobData.csv')

# Display basic info about the dataset
print(f"Dataset shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
print(f"\nFirst few job titles:")
print(df['title'].head(10))
# Out:
# Dataset shape: (1048575, 21)
#
# Columns: ['categories', 'employmentTypes', 'metadata_expiryDate', 'metadata_isPostedOnBehalf', 'metadata_jobPostId', 'metadata_newPostingDate', 'metadata_originalPostingDate', 'metadata_repostCount', 'metadata_totalNumberJobApplication', 'metadata_totalNumberOfView', 'minimumYearsExperience', 'numberOfVacancies', 'occupationId', 'positionLevels', 'postedCompany_name', 'salary_maximum', 'salary_minimum', 'salary_type', 'status_id', 'status_jobStatus', 'title']
#
# First few job titles:
# 0    Food Technologist - Clementi | Entry Level | U...
# 1    Software Engineer (Fab Support) (Java, CIM, Up...
# 2                                    Senior Technician
# 3    Senior .NET Developer (.NET Core, MVC, MVVC, S...
# 4                             Sales / Admin Cordinator
# 5                            Software Support Engineer
# 6    Urgent Hiring!!! Business Development Manager ...
# 7      IT Security Engineer (Maritime/ Cloud Security)
# 8    Assistant Sales Manager (Hunter Role)- Up to $...
# 9    Car Leasing, RM – West|Entry Level | Up to Bas...
# Name: title, dtype: object

# %%
# Define common job skills/keywords to look for in job titles
common_skills = [
    # Programming Languages
    'Python', 'Java', 'JavaScript', 'C++', 'C#', '.NET', 'ASP.NET', 'PHP', 'Ruby', 'Go', 'Rust', 'Swift', 'Kotlin',
    'Scala', 'TypeScript', 'HTML', 'CSS', 'SQL', 'R', 'MATLAB', 'Perl', 'Shell', 'Bash',
    # Frameworks & Technologies
    'React', 'Angular', 'Vue', 'Node.js', 'Django', 'Flask', 'Spring', 'Laravel', 'Express', 'ASP',
    'MVC', 'MVVM', 'REST', 'API', 'GraphQL', 'SOAP', 'Microservices', 'Docker', 'Kubernetes',
    'AWS', 'Azure', 'GCP', 'Cloud', 'DevOps', 'CI/CD', 'Jenkins', 'Git', 'GitHub', 'GitLab',
    # Databases
    'MySQL', 'PostgreSQL', 'MongoDB', 'Oracle', 'SQL Server', 'Redis', 'Elasticsearch', 'NoSQL',
    # Data & Analytics
    'Machine Learning', 'ML', 'Deep Learning', 'AI', 'Data Science', 'Data Analytics', 'Big Data',
    'Hadoop', 'Spark', 'Tableau', 'Power BI', 'Excel', 'Pandas', 'NumPy', 'TensorFlow', 'PyTorch',
    # Other Technologies
    'Linux', 'Unix', 'Windows', 'iOS', 'Android', 'Agile', 'Scrum', 'JIRA', 'Confluence',
    'SharePoint', 'Salesforce', 'SAP', 'ERP', 'CRM', 'Blockchain', 'IoT'
]

def extract_skills_from_title(title):
    """
    Extract skills mentioned in the job title.
    Returns a list of skills found in the title.
    """
    if pd.isna(title):
        return []
    
    title_str = str(title).upper()
    found_skills = []
    
    for skill in common_skills:
        # Check if skill is mentioned in the title (case-insensitive)
        if skill.upper() in title_str:
            found_skills.append(skill)
    
    return found_skills

# Apply the function to extract skills from job titles
df['job_skills'] = df['title'].apply(extract_skills_from_title)

# Convert list to string for better readability (comma-separated)
df['job_skills_mapped'] = df['job_skills'].apply(lambda x: ', '.join(x) if x else 'No specific skills mentioned')

# Display results
print("Sample of job titles with mapped skills:")
print(df[['title', 'job_skills_mapped']].head(20))
# Out:
# Sample of job titles with mapped skills:
#                                                 title  \
# 0   Food Technologist - Clementi | Entry Level | U...
# 1   Software Engineer (Fab Support) (Java, CIM, Up...
# 2                                   Senior Technician
# 3   Senior .NET Developer (.NET Core, MVC, MVVC, S...
# 4                            Sales / Admin Cordinator
# 5                           Software Support Engineer
# 6   Urgent Hiring!!! Business Development Manager ...
# 7     IT Security Engineer (Maritime/ Cloud Security)
# 8   Assistant Sales Manager (Hunter Role)- Up to $...
# 9   Car Leasing, RM – West|Entry Level | Up to Bas...
# 10  Electrical Engineer - Tuas | Generator exp|$4,700
# 11          Cook / Chef de Partie / Kitchen Assistant
# 12  Senior Accounts & Admin- Harbourfront | Constr...
# 13  Tech Lead (Backend, Ruby on Rails, AWS, Socket...
# 14    Sales Specialist/Manager, Molecular Diagnostics
# 15                   Senior  Cloud Migration Engineer
# 16                      Lead Cloud Migration Engineer
# 17                           Cloud Migration Engineer
# 18      CNC Machinist - Boon Lay / Basic up to $2,400
# 19  Brand & Communication Executive- Tuas| Up to $...
#
#                job_skills_mapped
# 0                              R
# 1                        Java, R
# 2                              R
# 3       .NET, R, MVC, SharePoint
# 4                              R
# 5                              R
# 6                              R
# 7                       R, Cloud
# 8                              R
# 9                              R
# 10                             R
# 11                             R
# 12                             R
# 13              Ruby, R, AWS, AI
# 14                             R
# 15                      R, Cloud
# 16                      R, Cloud
# 17                      R, Cloud
# 18  No specific skills mentioned
# 19                             R

# %%
# Save the updated dataframe with the new skills mapping column to CSV
# We'll save both the list format and the string format columns
df.to_csv('data/SGJobData.csv', index=False)

print(f"\nUpdated CSV saved successfully!")
print(f"New columns added: 'job_skills' (list) and 'job_skills_mapped' (string)")
print(f"\nStatistics:")
print(f"Jobs with skills identified: {(df['job_skills'].apply(len) > 0).sum()}")
print(f"Jobs without specific skills: {(df['job_skills'].apply(len) == 0).sum()}")
# Out:
# Updated CSV saved successfully!
# New columns added: 'job_skills' (list) and 'job_skills_mapped' (string)
#
# Statistics:
# Jobs with skills identified: 939552
# Jobs without specific skills: 109023

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit>=1.28.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.51.0)
# Collecting pandas>=2.0.0 (from -r requirements.txt (line 2))
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.24.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Collecting plotly>=5.17.0 (from -r requirements.txt (line 4))
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: seaborn>=0.12.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.12.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (8.3.0)
# Requirement already satisfied: packaging<26,>=20 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (6.33.0)
# Requirement already satisfied: pyarrow<22,>=7.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from streamlit>=1.28.0->-r requirements.txt (line 1)) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from pandas>=2.0.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from pandas>=2.0.0->-r requirements.txt (line 2)) (2025.2)
# Collecting tzdata>=2022.7 (from pandas>=2.0.0->-r requirements.txt (line 2))
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: jinja2 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (2.10.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28.0->-r requirements.txt (line 1)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28.0->-r requirements.txt (line 1)) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit>=1.28.0->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit>=1.28.0->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit>=1.28.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit>=1.28.0->-r requirements.txt (line 1)) (2025.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.28.0->-r requirements.txt (line 1)) (0.22.3)
# Requirement already satisfied: six>=1.5 in /home/darwin/miniconda3/envs/pds/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r requirements.txt (line 2)) (1.17.0)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 27.1 MB/s  0:00:00m0:00:010:01
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 13.7 MB/s  0:00:00m0:00:0100:01
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, plotly, pandas
#   Attempting uninstall: pandas╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [plotly]
#     Found existing installation: pandas 1.5.3━━━━━━━━━━━━━━━━━ 1/3 [plotly]
#     Uninstalling pandas-1.5.3:━━━━╸━━━━━━━━━━━━━ 2/3 [pandas]
#       Successfully uninstalled pandas-1.5.3╸━━━━━━━━━━━━━ 2/3 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed pandas-2.3.3 plotly-6.4.0 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
